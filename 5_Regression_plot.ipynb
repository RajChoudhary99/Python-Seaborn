# %% [markdown]
# Regression Plots - used for plotting regression line in machine learning
#
# regplot - axes level
# lmplot - figure level(no need to add kind parameter)
#
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
# axes level
# hue parameter is not available
sns.regplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
# residual plot(used  to find errors or residuals in regression model)
#points to +ve side are underpredicted and points to -ve side are overpredicted
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
